# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.linear_model import RidgeClassifier, SGDClassifier
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
import operator
import time

# %%
train_csv = pd.read_csv('dataset/train.csv')

# %%
train_csv.head(2)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
#
# [2 rows x 21 columns]

# %% [markdown]
# Additional Column in test for id, replaceing the  price range

# %%
train_csv.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
train_csv.price_range.value_counts()
# Out:
# 3    500
# 2    500
# 1    500
# 0    500
# Name: price_range, dtype: int64

# %% [markdown]
# Take all test as features. Train into class (last column) and the rest as features

# %%
train_np_data= np.array(train_csv.values.tolist())

# %%
train_features = train_np_data[:,:-1]
train_class = train_np_data[:,-1]

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(16, 6))
ax = sns.boxplot(data=train_features)

# %% [markdown]
# Scaling Data

# %%
scaler = MinMaxScaler()
scaler.fit(train_features)
print("Pre-scaled Data : {}".format(train_features))
train_features_scaled =  scaler.transform(train_features)
print("Scaled Data : {}".format(train_features_scaled))
# Out:
# Pre-scaled Data : [[8.420e+02 0.000e+00 2.200e+00 ... 0.000e+00 0.000e+00 1.000e+00]
#  [1.021e+03 1.000e+00 5.000e-01 ... 1.000e+00 1.000e+00 0.000e+00]
#  [5.630e+02 1.000e+00 5.000e-01 ... 1.000e+00 1.000e+00 0.000e+00]
#  ...
#  [1.911e+03 0.000e+00 9.000e-01 ... 1.000e+00 1.000e+00 0.000e+00]
#  [1.512e+03 0.000e+00 9.000e-01 ... 1.000e+00 1.000e+00 1.000e+00]
#  [5.100e+02 1.000e+00 2.000e+00 ... 1.000e+00 1.000e+00 1.000e+00]]
# Scaled Data : [[0.22778891 0.         0.68       ... 0.         0.         1.        ]
#  [0.34736139 1.         0.         ... 1.         1.         0.        ]
#  [0.04141617 1.         0.         ... 1.         1.         0.        ]
#  ...
#  [0.94188377 0.         0.16       ... 1.         1.         0.        ]
#  [0.6753507  0.         0.16       ... 1.         1.         1.        ]
#  [0.00601202 1.         0.6        ... 1.         1.         1.        ]]

# %%
import main

# %%
main.heat_map(train_csv)

# %% [markdown]
# ## Dim Reduction Trial

# %%
clf= DecisionTreeClassifier()
scores = cross_val_score(clf,train_features_scaled,train_class,cv=10)
print("Original Accuracy is ",np.mean(scores))
# Out:
# Original Accuracy is  0.8355

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)
pca.fit(train_features_scaled) 
pca_train_features_scaled = pca.transform(train_features_scaled)
print ("Explained Variance: ",np.sum(pca.explained_variance_ratio_))
# Out:
# Explained Variance:  0.23217819888825275

# %%
clf= DecisionTreeClassifier()
scores = cross_val_score(clf,pca_train_features_scaled,train_class,cv=10)
print("After DIM Reduction/PCA Accuracy is ",np.mean(scores))
# Out:
# After DIM Reduction/PCA Accuracy is  0.26799999999999996

# %% [markdown]
# ## Graphs of feature selection/removal and accuracies with different models

# %%
data_train, data_test, class_train, class_test = main.split_data(train_features_scaled, train_class)
main.classification_models(data_train, data_test, class_train, class_test)
# Out:
# ########## KNN #########
#
# KNN - Cross Val Mean : 0.39875 , Cross Val Std Dev : 0.05190134873006674
#
# Confusion Matrix :
#
# [[64 29 15  5]
#  [26 33 31 20]
#  [14 23 32 49]
#  [ 1  6 14 38]]
# Classification Report :
#
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.57      0.59       113
#          1.0       0.36      0.30      0.33       110
#          2.0       0.35      0.27      0.30       118
#          3.0       0.34      0.64      0.44        59
#
#     accuracy                           0.42       400
#    macro avg       0.41      0.45      0.42       400
# weighted avg       0.42      0.42      0.41       400
#
# ########## END OF KNN #########
#
# ########## Random Forest #########
#
# Random Forest - Cross Val Mean : 0.8637500000000001 , Cross Val Std Dev : 0.014197270864500676
#
# Confusion Matrix :
#
# [[101   5   0   0]
#  [  4  79   6   0]
#  [  0   7  80  15]
#  [  0   0   6  97]]
# Classification Report :
#
# ...

# %%
best_models = main.feature_removal(data_train, data_test, class_train, class_test)
# Out:
# KNN Max Accuracy : 0.8724999999999999
# Random Forest Max Accuracy : 0.875
# SVM Max Accuracy : 0.9175000000000001
# Ridge Max Accuracy : 0.6224999999999999
# SGD Max Accuracy : 0.7725
# Decision Tree Max Accuracy : 0.8150000000000001
# GNB Max Accuracy : 0.8400000000000001
# XGBoost Max Accuracy : 0.8600000000000001
# Models ranked from best to worst : [('SVM', 0.9175000000000001), ('Random Forest', 0.875), ('KNN', 0.8724999999999999), ('XGBoost', 0.8600000000000001), ('GNB', 0.8400000000000001), ('Decision Tree', 0.8150000000000001), ('SGD', 0.7725), ('Ridge', 0.6224999999999999)]

# %%
random_model = RandomForestClassifier(random_state=42)
random_fit = random_model.fit(data_train, class_train)
rank_models = []
train_features_pd = train_csv.copy()
train_features_pd = train_features_pd.drop(["price_range"],axis=1)
train_features_pd
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
feat_importances = pd.Series(random_model.feature_importances_, index=train_features_pd.columns)
feat_importances.nlargest(20).plot(kind='bar')
plt.show()

# %%
def uni_variate_feature_selection(model_name, train_scaled_data, train_class):
    """
    :param model_name: Name of  baseline model to use
    :param train_scaled_data: The min-max/normalized data
    :param train_class: The target value
    """
    # Need to use minMaxScaler for chi2 and SelectKBest// NO NEGATIVE VALUES
    # This reduces accuracy
    # Select top 4/ as max. accuracy obtained with 16 indexes removed, leaving 4 so take the 4
    k_best_features = SelectKBest(chi2, k=4).fit_transform(train_scaled_data, train_class)
    print(k_best_features)
    data_train, data_test, class_train, class_test = main.split_data(k_best_features, train_class)
    model = best_models(model_name)
    model.fit(data_train, class_train)
    prediction = model.predict(data_test)
    print(model_name + " Confusion matrix univariate:\n {}".
          format(metrics.confusion_matrix(class_test, prediction)))
    print(model_name + " Classification report  univariate :\n {}".
          format(metrics.classification_report(class_test, prediction)))
    features_scores = cross_val_score(model, data_train, class_train, cv=10)
    print(model_name+" Univariate Mean scores : {}".format(features_scores.mean()))
    print("End of "+model_name+" univariate feature selection with optimized hyperparameters")

# %%
def best_models(model_name):
    if model_name == "SVM":
        model = SVC(kernel='linear', C=10, gamma=0.001)
    elif model_name == "RF":
        model = RandomForestClassifier(max_depth=55, n_estimators=1000)
    else:
        model = KNeighborsClassifier(n_neighbors=73, p=1)
    return model

# %%
uni_variate_feature_selection("SVM", train_features_scaled, train_class)
# Out:
# [[0.22778891 0.01020408 0.17089453 0.61277392]
#  [0.34736139 0.46173469 0.99332443 0.63468733]
#  [0.04141617 0.64438776 0.811749   0.6272047 ]
#  ...
#  [0.94188377 0.44285714 0.75567423 0.7485302 ]
#  [0.6753507  0.17142857 0.11348465 0.16381614]
#  [0.00601202 0.24642857 0.16955941 0.9788883 ]]
# SVM Confusion matrix univariate:
#  [[103   2   0   0]
#  [  0  91   0   0]
#  [  0   3  86   3]
#  [  0   0   4 108]]
# SVM Classification report  univariate :
#                precision    recall  f1-score   support
#
#          0.0       1.00      0.98      0.99       105
#          1.0       0.95      1.00      0.97        91
#          2.0       0.96      0.93      0.95        92
#          3.0       0.97      0.96      0.97       112
#
#     accuracy                           0.97       400
#    macro avg       0.97      0.97      0.97       400
# weighted avg       0.97      0.97      0.97       400
#
# SVM Univariate Mean scores : 0.95375
# ...

# %%
def optimize(model, data_train, class_train):
    """
    GridCV for the top performing models after two rounds of classification
    1. Without Feature Selection/Importance
    2. With Feature Importance
    :param model: name of model
    :param data_train:
    :param class_train:
    :return:
    """
    start_time = time.time()
    if model == "SVM":
        print("$$$$$$$$$$$$$$$$$$$$$ BEGINNING SVM Hyperparameter optimization $$$$$$$$$$$$$$$$$$$$")
        svm_param_grid = [{'kernel': ['linear', 'rbf'], 'C': [0.001, 0.01, 0.1, 1, 10], 'gamma':[0.001, 0.01, 0.1, 1]}]
        svm_clf = GridSearchCV(SVC(), svm_param_grid, n_jobs=-1, cv=10)
        svm_clf.fit(data_train, class_train)
        print("Best Parameters with SVM Linear Kernal:")
        print(svm_clf.best_params_, 'with a score of ', svm_clf.best_score_)
        print("$$$$$$$$$$$$$$$$$$$$$ ENDING SVM Hyperparameter optimization $$$$$$$$$$$$$$$$$$$$")
        # Best Parameters with SVM RBF Kernel:
        # {'C': 10, 'gamma': 0.001} with a score of  0.9181250000000001
        # Best Parameters with SVM Linear Kernal:
        # {'C': 1, 'gamma': 0.001} with a score of  0.959375
    return svm_clf.best_params_, svm_clf.best_score_

best_param, best_score = optimize("SVM", data_train, class_train)
# Out:
# $$$$$$$$$$$$$$$$$$$$$ BEGINNING SVM Hyperparameter optimization $$$$$$$$$$$$$$$$$$$$
# Best Parameters with SVM Linear Kernal:
# {'C': 10, 'gamma': 0.001, 'kernel': 'linear'} with a score of  0.9575000000000001
# $$$$$$$$$$$$$$$$$$$$$ ENDING SVM Hyperparameter optimization $$$$$$$$$$$$$$$$$$$$

# %%
test = []
for k,v in best_param.items():
    test.append((k,v))
print(test)
config = ""
for item in test:
    config = item[0]+"= "+str(item[1])
print(config)
# Out:
#   File "<ipython-input-59-2264999e9bb0>", line 7
#     config = item[0]+"= "str(item[1])
#                            ^
# SyntaxError: invalid syntax
